# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
parsnp_data = pd.read_csv('/home/Users/rdd4/bronko_test/alignment_comparisons/sars_evolution_results/parsnp_consensus/parsnp.vcf', delimiter='\t', skiprows=5)

# %%
parsnp_data[~parsnp_data['ALT'].isin(['A','C','G','T'])]
# Out:
#         #CHROM    POS                     ID REF  ALT  QUAL FILTER  INFO  \
# 26   Ancestral   1567  CATAGAACTG.CGTTTAAGAT   C  A,T    40   PASS   NaN
# 189  Ancestral  10406  GCTCTTTAGG.TATTCATAGC   T  G,C    40   PASS   NaN
# 238  Ancestral  13357  CACTTGTGAA.ATAACACTTG   A  G,C    40   PASS   NaN
# 242  Ancestral  13694  CACAAATGGC.TATCTGATTT   T  G,C    40   PASS   NaN
# 302  Ancestral  15968  TATAATTCAG.GAATAATCAT   G  T,A    40   PASS   NaN
# 371  Ancestral  19710  AGAGTGCTGC.AATTTTTGAT   A  T,G    40   PASS   NaN
#
#     FORMAT  ancestral_sequence.fa.ref  ...  1090-3570-0.112577.fasta  \
# 26      GT                          0  ...                         0
# 189     GT                          0  ...                         0
# 238     GT                          0  ...                         0
# 242     GT                          0  ...                         0
# 302     GT                          0  ...                         0
# ...

# %%
df = parsnp_data
df['alt_index_list'] = df['ALT'].apply(lambda alts: list(range(1, len(alts)+1)))
df = df.explode(['ALT', 'alt_index_list']).reset_index(drop=True)
df['alt_index_list'] = df['alt_index_list'].astype(int)

# 2️⃣ fix fasta columns
for col in fasta_cols:
    df[col] = (df[col] == df['alt_index_list']).astype(int)

# 3️⃣ cleanup
df = df.drop(columns='alt_index_list')

# %%
parsnp_data['POS'] = parsnp_data['POS'].astype(int)

# %%
import os
import pandas as pd

vcf_dir = "/home/Users/rdd4/bronko_test/alignment_comparisons/sars_evolution_results/bronko_single_ref"  # change this to your VCF folder path
vcf_files = [f for f in os.listdir(vcf_dir) if f.endswith(".vcf")]


variant_dict = {}

for vcf_file in vcf_files:
    sample_name = vcf_file.replace(".vcf", ".fasta")
    with open(os.path.join(vcf_dir, vcf_file)) as f:
        for line in f:
            if line.startswith("#"):
                continue
            fields = line.strip().split("\t")
            chrom, pos, _, ref, alt = fields[:5]
            key = (chrom, pos, ref, alt)
            if key not in variant_dict:
                variant_dict[key] = {}
            variant_dict[key][sample_name] = 1
            
print(variant_dict)

# convert to DataFrame

bronko = pd.DataFrame.from_dict(variant_dict, orient="index")
bronko = bronko.fillna(0).astype(int)
bronko.reset_index(inplace=True)
bronko.rename(columns={"index": ["CHROM", "POS", "REF", "ALT"]}, inplace=True)

new_names = ['#CHROM','POS','REF','ALT']
bronko.columns = new_names + bronko.columns[4:].tolist()
bronko['POS'] = bronko['POS'].astype(int)
bronko

# df = bronko.drop(columns='index')

# # save table

# # df.to_csv("variant_presence_matrix.csv", index=False)
# print("Saved variant presence matrix to variant_presence_matrix.csv")
# Out:
# {('Ancestral', '6388', 'T', 'C'): {'659-7827-0.129215.fasta': 1, '199-99-0.164007.fasta': 1, '286-3036-0.159561.fasta': 1, '1174-9602-0.106911.fasta': 1, '765-6965-0.125270.fasta': 1, '16-3743-0.240767.fasta': 1, '2024-1707-0.066030.fasta': 1, '1416-9856-0.087780.fasta': 1, '733-3924-0.128434.fasta': 1, '1839-6616-0.071935.fasta': 1, '1708-461-0.086237.fasta': 1, '1738-41-0.089304.fasta': 1, '499-1187-0.148721.fasta': 1, '410-7883-0.145812.fasta': 1, '529-1386-0.161001.fasta': 1, '1989-3131-0.067958.fasta': 1, '1745-63-0.082769.fasta': 1, '993-2379-0.141732.fasta': 1, '1816-445-0.086718.fasta': 1, '959-5503-0.109298.fasta': 1, '212-3391-0.190811.fasta': 1, '1064-5598-0.110931.fasta': 1, '796-573-0.117259.fasta': 1, '806-2593-0.137712.fasta': 1, '1735-8837-0.075900.fasta': 1, '870-3005-0.126122.fasta': 1, '1809-1763-0.092410.fasta': 1, '1548-3006-0.095750.fasta': 1, '476-2467-0.161842.fasta': 1, '903-4365-0.125545.fasta': 1, '50-661-0.219629.fasta': 1, '1921-2343-0.072007.fasta': 1, '
# ...

# %%
variant_cols = ["#CHROM", "POS", "REF", "ALT"]
sample_cols = [c for c in bronko.columns if c not in variant_cols]

merged = pd.merge(parsnp_data, bronko, on=variant_cols, how="outer", suffixes=("_1", "_2"))

results = []
for c in sample_cols:
    print(c)
    df1_total = merged[c + "_1"].sum()
    df2_total = merged[c + "_2"].sum()
    shared_snps = ((merged[c + "_1"] == 1) & (merged[c + "_2"] == 1)).sum()
    results.append({"sample": c, "df1_total": df1_total, "df2_total": df2_total, "shared_snps": shared_snps})

overlap_df = pd.DataFrame(results)
overlap_df
# Out:
# 659-7827-0.129215.fasta
# 199-99-0.164007.fasta
# 286-3036-0.159561.fasta
# 1174-9602-0.106911.fasta
# 765-6965-0.125270.fasta
# 16-3743-0.240767.fasta
# 2024-1707-0.066030.fasta
# 1416-9856-0.087780.fasta
# 733-3924-0.128434.fasta
# 1839-6616-0.071935.fasta
# 1708-461-0.086237.fasta
# 1738-41-0.089304.fasta
# 499-1187-0.148721.fasta
# 410-7883-0.145812.fasta
# 529-1386-0.161001.fasta
# 1989-3131-0.067958.fasta
# 1745-63-0.082769.fasta
# 993-2379-0.141732.fasta
# 1816-445-0.086718.fasta
# 959-5503-0.109298.fasta
# 212-3391-0.190811.fasta
# 1064-5598-0.110931.fasta
# 796-573-0.117259.fasta
# 806-2593-0.137712.fasta
# 1735-8837-0.075900.fasta
# 870-3005-0.126122.fasta
# 1809-1763-0.092410.fasta
# 1548-3006-0.095750.fasta
# 476-2467-0.161842.fasta
# 903-4365-0.125545.fasta
# 50-661-0.219629.fasta
# 1921-2343-0.072007.fasta
# 1507-380-0.086553.fasta
# 1626-3448-0.089205.fasta
# 554-2356-0.145751.fasta
# 663-9278-0.131761.fasta
# 202-4238-0.169615.fasta
# 208-6591-0.176254.fasta
# ...

# %%
int(overlap_df['df1_total'].sum()), overlap_df['df2_total'].sum(), overlap_df['shared_snps'].sum()
# Out:
# (3655, np.float64(3647.0), np.int64(3621))
